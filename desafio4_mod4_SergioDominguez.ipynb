# %% [markdown]
# # Descripción
# La base de datos world-data-2023.csv proporciona una gran cantidad de información sobre
# todos los países del mundo, abarcando una amplia gama de indicadores y atributos. Incluye
# estadísticas demográficas, indicadores económicos, factores ambientales, métricas de
# atención médica, estadísticas educativas y mucho más. Con la representación de cada país,
# este conjunto de datos ofrece una perspectiva global completa sobre diversos aspectos de
# las naciones, lo que permite análisis en profundidad y comparaciones entre países. Las
# variables consideradas son:
# ● 0. Country: Nombre del país.
# ● 1. Density (P/Km2): Densidad de población medida en personas por kilómetro cuadrado.
# ● 2. Abbreviation: Abreviatura o código que representa el país.
# ● 3. Agricultural Land (%): Porcentaje del área de tierra utilizada para fines agrícolas.
# ● 4. Land Area (Km2): Área total de tierra del país en kilómetros cuadrados.
# ● 5. Armed Forces Size: Tamaño de las fuerzas armadas en el país.
# ● 6. Birth Rate: Número de nacimientos por 1,000 habitantes por año.
# ● 7. Calling Code: Código de llamada internacional para el país.
# ● 8. Capital/Major City: Nombre de la capital o ciudad principal.
# ● 9. CO2 Emissions: Emisiones de dióxido de carbono en toneladas.
# ● 10. CPI: Índice de Precios al Consumidor, una medida de la inflación y el poder adquisitivo.
# ● 11. CPI Change (%): Cambio porcentual en el Índice de Precios al Consumidor encomparación con el año anterior.
# ● 12. Currency_Code: Código de moneda utilizado en el país.
# ● 13. Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
# ● 14. Forested Area (%): Porcentaje del área de tierra cubierta por bosques.
# ● 15. Gasoline_Price: Precio de la gasolina por litro en moneda local.
# ● 16. GDP: Producto Interno Bruto, el valor total de bienes y servicios producidos en el país.
# ● 17. Gross Primary Education Enrollment (%): Tasa de inscripción bruta en educación primaria.
# ● 18. Gross Tertiary Education Enrollment (%): Tasa de inscripción bruta en educación terciaria.
# ● 19. Infant Mortality: Número de muertes por cada 1,000 nacidos vivos antes de cumplir un año de edad.
# ● 20. Largest City: Nombre de la ciudad más grande del país.
# ● 21. Life Expectancy: Número promedio de años que se espera que viva un recién nacido.
# ● 22. Maternal Mortality Ratio: Número de muertes maternas por cada 100,000 nacidos vivos.
# ● 23. Minimum Wage: Nivel de salario mínimo en moneda local.
# ● 24. Official Language: Idioma(s) oficial(es) hablado(s) en el país.
# ● 25. Out of Pocket Health Expenditure (%): Porcentaje del gasto total en salud pagado directamente por los individuos.
# ● 26. Physicians per Thousand: Número de médicos por cada mil personas.
# ● 27. Population: Población total del país.
# ● 28. Population: Labor Force Participation (%): Porcentaje de la población que forma parte de la fuerza laboral.
# ● 29. Tax Revenue (%): Ingresos fiscales como porcentaje del PIB.
# ● 30. Total Tax Rate: Carga tributaria total como porcentaje de las ganancias comerciales.
# ● 31. Unemployment Rate: Porcentaje de la fuerza laboral que está desempleada.
# ● 32. Urban Population: Porcentaje de la población que vive en áreas urbanas.
# ● 33. Latitude: Coordenada de latitud de la ubicación del país.
# ● 34. Longitude: Coordenada de longitud de la ubicación del país.
#
# Vamos a realizar algunos análisis comparativos entre las variables. Para ello:

# %% [markdown]
# 1. Carga los datos y genera un dataFrame que excluya las columnas correspondientes
# a la abreviatura del país, código de llamada, capital, código de moneda, ciudad más
# grande, lenguaje oficial, latitud y longitud. Considerando estos datos, realiza una
# inspección inicial sobre ellos, considerando gráficos. Concluye.

# %%
# omportar librerias
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# cargar informacion
df_world = pd.read_csv('world-data-2023.csv')

# %%
# revisar estructura de la data
df_world.info()     # informacion general del df
print(df_world.shape)   # dimension del data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
# eliminar columnas indicadas del set de datos
# lista de columnas a eliminar del df
columnas_a_omitir = ["Abbreviation", "Calling Code", "Capital/Major City", "Currency-Code", 
                     "Largest city", "Official language", "Latitude", "Longitude"
                    ]
# omitir columnas del df y actualizo el dataframe
df_world.drop(columns = columnas_a_omitir, inplace = True)
df_world
# Out:
#          Country Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# 0    Afghanistan               60                58.10%        652,230
# 1        Albania              105                43.10%         28,748
# 2        Algeria               18                17.40%      2,381,741
# 3        Andorra              164                40.00%            468
# 4         Angola               26                47.50%      1,246,700
# ..           ...              ...                   ...            ...
# 190    Venezuela               32                24.50%        912,050
# 191      Vietnam              314                39.30%        331,210
# 192        Yemen               56                44.60%        527,968
# 193       Zambia               25                32.10%        752,618
# 194     Zimbabwe               38                41.90%        390,757
#
#     Armed Forces size  Birth Rate Co2-Emissions       CPI CPI Change (%)  \
# ...

# %%
# existen valores de columnas numericas (float) con simbolos de $ % y ,
# eliminacion de simbolos para convertir valores a float
# lista de columnas a omitir (dejo fuera de la rutina la columna country)
columnas_a_omitir = ["Country"]
columnas=df_world.drop(columns=columnas_a_omitir).columns
# corregimos los datos, a flotantes
for columna in columnas:
    df_world[columna] = df_world[columna]\
    .apply(lambda x: float(str(x)\
            .replace('%','')\
            .replace('$','')\
            .replace(',','')))

# %%
# revision del dataframe
print("**********")
print(df_world.shape)   # dimension del data
print("**********")
print(df_world.describe())  # obtener valores estadisticos
print("**********")
print(df_world.dtypes)  # ver tipo de datos
print("**********")
print(df_world.info())  # ver informacion de datos
# Out:
# **********
# (195, 27)
# **********
#        Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# count        195.000000             188.000000    1.940000e+02
# mean         356.764103              39.117553    6.896244e+05
# std         1982.888967              21.783052    1.921609e+06
# min            2.000000               0.600000    0.000000e+00
# 25%           35.500000              21.700000    2.382825e+04
# 50%           89.000000              39.600000    1.195110e+05
# 75%          216.500000              55.375000    5.242560e+05
# max        26337.000000              82.600000    1.709824e+07
#
#        Armed Forces size  Birth Rate  Co2-Emissions          CPI  \
# count       1.710000e+02  189.000000   1.880000e+02   178.000000
# mean        1.592749e+05   20.214974   1.777992e+05   190.460955
# std         3.806288e+05    9.945774   8.387903e+05   397.947380
# min         0.000000e+00    5.900000   1.100000e+01    99.030000
# ...

# %%
# identifico por columnas la cantidad de valores nan
# esto para tenerlo en consideracion en los analisis de los proximos puntos
print("** lista de valores nan ********")
print(df_world.isna().sum())   # revisar si existen valores nan
# Out:
# ** lista de valores nan ********
# Country                                       0
# Density\n(P/Km2)                              0
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# ...

# %%
# graficar columnas
columna="Agricultural Land( %)"
sns.histplot(data=df_world, x=columna, kde = True, bins=20)
plt.axvline(df_world[columna].mean(), color='red', linestyle='dashed', linewidth=2, label='Media')
plt.title('Distribución real con la media para ' + columna)
plt.legend()
plt.show()

# graficar columnas
columna="GDP"
sns.histplot(data=df_world, x=columna, kde = True, bins=20)
plt.axvline(df_world[columna].mean(), color='red', linestyle='dashed', linewidth=2, label='Media')
plt.title('Distribución real con la media para ' + columna)
plt.legend()
plt.show()

# graficar columnas
columna="Population"
sns.histplot(data=df_world, x=columna, kde = True, bins=20)
plt.axvline(df_world[columna].mean(), color='red', linestyle='dashed', linewidth=2, label='Media')
plt.title('Distribución real con la media para ' + columna)
plt.legend()
plt.show()

# %% [markdown]
# 2. De las variables codificadas numéricamente, ¿hay pares de ellas en la que parezca
# haber correlación? ¿Para cuál(es) de ellas se observa más claramente?

# %%
# utilizo funcion de correlacion de pandas
# omito de la funcion de correlacion la columnas que no son numericas
columnas_a_omitir = ["Country"]
df_correlaciones = df_world.drop(columns=columnas_a_omitir).corr()
df_correlaciones
# Out:
#                                            Density\n(P/Km2)  \
# Density\n(P/Km2)                                   1.000000
# Agricultural Land( %)                             -0.108478
# Land Area(Km2)                                    -0.053279
# Armed Forces size                                  0.000526
# Birth Rate                                        -0.147024
# Co2-Emissions                                     -0.014262
# CPI                                               -0.043356
# CPI Change (%)                                    -0.052459
# Fertility Rate                                    -0.149302
# Forested Area (%)                                 -0.100466
# Gasoline Price                                     0.224889
# GDP                                               -0.017690
# Gross primary education enrollment (%)             0.009727
# Gross tertiary education enrollment (%)            0.109555
# Infant mortality                                  -0.106076
# ...

# %%
# genero grafico con las correlaciones sobre un 0.9 de coeficiente de correlacion
plt.figure(figsize=(10,10))
ax =sns.heatmap(df_correlaciones[(df_correlaciones > 0.9)\
                | (df_correlaciones < -0.9)], cmap = 'Reds', annot = True)

# %% [markdown]
# # para responder la segunda pregunta, ¿Para cuál(es) de ellas se observa más claramente?
# # encontre los sgtes Pares de columnas con un alto coeficiente de correlacion entre ellas
# # par 1
# # 13. Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
# # 6. Birth Rate: Número de nacimientos por 1,000 habitantes por año.
#
# # par 2
# # 16. GDP: Producto Interno Bruto, el valor total de bienes y servicios producidos en el país
# # 9. CO2 Emissions: Emisiones de dióxido de carbono en toneladas.
#
# # par 3
# # 32. Urban Population: Porcentaje de la población que vive en áreas urbanas.
# # 9. CO2 Emissions: Emisiones de dióxido de carbono en toneladas.
#
# # par 4
# # 32. Urban Population: Porcentaje de la población que vive en áreas urbanas.
# # 27. Population: Población total del país.

# %% [markdown]
# 3. Considera los dos pares de variables anteriores y elimina en cada caso los faltantes
# y atípicos. Justifica en cada caso tu procedimiento.

# %%
#selecciono el par 1 y proceso a aplicar procedimiento de filtrado y limpieza
# par 1
# 13. Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
# 6. Birth Rate: Número de nacimientos por 1,000 habitantes por año.
sns.boxplot(data=df_world, x='Fertility Rate')
# Out:
# <Axes: xlabel='Fertility Rate'>

# %% [markdown]
# # Nota: el grafico para la columna Fertility Rate, muestra valores atipicos (outliers)

# %%
# par 1
# 13. Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
# 6. Birth Rate: Número de nacimientos por 1,000 habitantes por año.
sns.boxplot(data=df_world, x='Birth Rate')
# Out:
# <Axes: xlabel='Birth Rate'>

# %% [markdown]
# # Nota: el grafico para la columna Birth Rate, no muestra valores atipicos (outliers)

# %%
# identifico por columnas la cantidad de valores nan
print("** lista de valores nan ********")
df_world['Fertility Rate'].isna().sum()
df_world['Birth Rate'].isna().sum()

# %%
# ahora buscare los valores atipicos (outliers) y los filtrare
# genero variable data con la columna sin los valores nan
data = df_world['Fertility Rate'].dropna()
# calculo el percentil q1 y q3
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
# calculo que rango intercuartil
IQR = Q3 - Q1
# alteramos la escala (1.5) para dejar fuera los valores atipicos dentro del dataframe
# regla que estima alta sensibilidad para considerar datos que no sean valores atipicos
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# visualizo los registros de valores atipicos para columna Fertility Rate con los nuevos puntos inferior y superior
df_world[(df_world['Fertility Rate'] <= lower_bound) | (df_world['Fertility Rate'] >= upper_bound)]
# Out:
#     Country  Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 125   Niger              19.0                   36.1       1267000.0
#
#      Armed Forces size  Birth Rate  Co2-Emissions     CPI  CPI Change (%)  \
# 125            10000.0       46.08         2017.0  109.32            -2.5
#
#      Fertility Rate  ...  Maternal mortality ratio  Minimum wage  \
# 125            6.91  ...                     509.0          0.29
#
#      Out of pocket health expenditure  Physicians per thousand  Population  \
# 125                              52.3                     0.04  23310715.0
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 125                                       72.0             11.8
#
#      Total tax rate  Unemployment rate  Urban_population
# 125            47.2               0.47         3850231.0
#
# [1 rows x 27 columns]

# %%
# actualizo el dataframe
#df_world.iloc[np.where((data>= lower_bound) * (data <= upper_bound))]
# esta linea de codigo no me satisface, la revisare con mas detalles
# solo tengo un registro con valores atipicos y procedere a eliminar por el indice
# genero un nuevo df normalizado
df_world_fr_normal = df_world.drop(index=125)

# %%
#verifico el total de registros
# el original son 195, ahora normalizado tengo 194
print(df_world_fr_normal.shape)   # dimension del data
# Out:
# (194, 27)

# %% [markdown]
# 4. Construye un gráfico para verificar la correlación entre estas variables, ahora con los
# datos preparados. Compara con lo obtenido anteriormente.

# %%
# genero nuevamente correlacion
# utilizo funcion de correlacion de pandas
# omito de la funcion de correlacion la columnas que no son numericas
columnas_a_omitir = ["Country"]
df_correlaciones_2 = df_world_fr_normal.drop(columns=columnas_a_omitir).corr()
#df_correlaciones_2[['Fertility Rate','Birth Rate']]
df_correlaciones_2.loc[['Fertility Rate','Birth Rate'],['Fertility Rate','Birth Rate']]
# Out:
#                 Fertility Rate  Birth Rate
# Fertility Rate        1.000000    0.981516
# Birth Rate            0.981516    1.000000

# %%
# genero grafico con las correlaciones sobre un 0.9 de coeficiente de correlacion
#plt.figure(figsize=(10,10))
#ax =sns.heatmap(df_correlaciones_2[(df_correlaciones_2 > 0.9)\
#                | (df_correlaciones_2 < -0.9)], cmap = 'Reds', annot = True)
# 13. Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
# 6. Birth Rate: Número de nacimientos por 1,000 habitantes por año.
print("Correlacion sin filtracion ni limpieza")
plt.figure(figsize=(5,5))
ax = sns.heatmap(df_correlaciones.loc[['Fertility Rate','Birth Rate'],['Fertility Rate','Birth Rate']], cmap = 'Reds', annot = True)
# Out:
# Correlacion sin filtracion ni limpieza

# %%
print("Correlacion com filtracion ni limpieza")
plt.figure(figsize=(5,5))
ax = sns.heatmap(df_correlaciones_2.loc[['Fertility Rate','Birth Rate'],['Fertility Rate','Birth Rate']], cmap = 'Reds', annot = True)
# Out:
# Correlacion com filtracion ni limpieza

# %% [markdown]
# # Nota: para las columnas Fertility Rate y Birth Rate, la limpieza y limpieza, que solo necesitaba Fertility Rate
# # y corresponde a un solo registro
# # no afecta la correlacion

# %% [markdown]
# 5. Realiza lo mismo para comparar la cantidad de médicos por cada mil personas y la
# esperanza de vida. ¿Qué puedes concluir?
# columnas 'Physicians per thousand','Life expectancy'

# %%
# identifico por columnas la cantidad de valores nan
print("** lista de valores nan ********")
df_world['Physicians per thousand'].isna().sum()
print("**")
df_world['Life expectancy'].isna().sum()
# Out:
# ** lista de valores nan ********
# **
# 8

# %% [markdown]
# # respecto de nan solo la columna Life expectancy tiene 8 registros

# %%
# grafico la columna en busca de valores atipicos
sns.boxplot(data=df_world, x='Physicians per thousand')
# Out:
# <Axes: xlabel='Physicians per thousand'>

# %%
# grafico la columna en busca de valores atipicos
sns.boxplot(data=df_world, x='Life expectancy')
# Out:
# <Axes: xlabel='Life expectancy'>

# %%
# solo tengo valores atipicos en columna Physicians per thousand
# aplico procedimiento de filtrado
# ahora buscare los valores atipicos (outliers) y los filtrare
# genero variable data con la columna sin los valores nan
data = df_world['Physicians per thousand'].dropna()
# calculo el percentil q1 y q3
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
# calculo que rango intercuartil
IQR = Q3 - Q1
# alteramos la escala (1.5) para dejar fuera los valores atipicos dentro del dataframe
# regla que estima alta sensibilidad para considerar datos que no sean valores atipicos
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# visualizo los registros de valores atipicos para columna Physicians per thousand con los nuevos puntos inferior y superior
df_world[(df_world['Physicians per thousand'] <= lower_bound) | (df_world['Physicians per thousand'] >= upper_bound)]
# Out:
#     Country  Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 42     Cuba             106.0                   59.9        110860.0
# 63  Georgia              57.0                   34.5         69700.0
#
#     Armed Forces size  Birth Rate  Co2-Emissions     CPI  CPI Change (%)  \
# 42            76000.0       10.17        28284.0     NaN             NaN
# 63            26000.0       13.47        10128.0  133.61             4.9
#
#     Fertility Rate  ...  Maternal mortality ratio  Minimum wage  \
# 42            1.62  ...                      36.0          0.05
# 63            2.06  ...                      25.0          0.05
#
#     Out of pocket health expenditure  Physicians per thousand  Population  \
# 42                               NaN                     8.42  11333483.0
# 63                              57.3                     7.12   3720382.0
#
#     Population: Labor force participation (%)  Tax revenue (%)  \
# ...

# %% [markdown]
# # mmmmmmmmmmmmmmmmmmmmm
# # tengo entendido que el sistema de salud en cuba es buenisimo
# # y que la politica publica al respecto es buena, la universidad y los hospitales estan "conectados"
# # por asi decirlo, respecto de medicina
# # no me pareceria extraño que el valor de medicos este elevado y pareciera ser atipico
# # desconosco respecto de Georgia
# # dado lo anterior, no eliminare valores atipicos y vere la correlacion de las dos columnas

# %%
# grafico la correlacion
plt.figure(figsize=(5,5))
ax = sns.heatmap(df_correlaciones.loc[['Physicians per thousand','Life expectancy'],['Physicians per thousand','Life expectancy']], cmap = 'Reds', annot = True)

# %%
# reviso los paises ordenados por la columna poblacion
by_Physicians = df_world.sort_values('Physicians per thousand',ascending=False)
by_Physicians[['Country','Physicians per thousand','Life expectancy']].head()
# Out:
#         Country  Physicians per thousand  Life expectancy
# 42         Cuba                     8.42             78.7
# 63      Georgia                     7.12             73.6
# 113      Monaco                     6.56              NaN
# 99    Lithuania                     6.35             75.7
# 149  San Marino                     6.11             85.4

# %%
# reviso los paises ordenados por la columna poblacion
by_Life = df_world.sort_values('Life expectancy',ascending=False)
by_Life[['Country','Life expectancy','Physicians per thousand']].head(40)
# Out:
#                  Country  Life expectancy  Physicians per thousand
# 149           San Marino             85.4                     6.11
# 85                 Japan             84.2                     2.41
# 169          Switzerland             83.6                     4.30
# 164                Spain             83.3                     3.87
# 156            Singapore             83.1                     2.29
# 98         Liechtenstein             83.0                      NaN
# 83                 Italy             82.9                     3.98
# 82                Israel             82.8                     4.62
# 129               Norway             82.8                     2.92
# 76               Iceland             82.7                     4.08
# 8              Australia             82.7                     3.68
# 162          South Korea             82.6                     2.36
# 60                France             82.5                     3.27
# ...

# %% [markdown]
# # Nota: efectivamente el coeficiente de correlacion es bajo para estas dos columnas
# # al revisar los datos cuba es el que tien mas medicos por 1000 personas, pero su expectativa de vida es
# # buena, se condice con japon que es el segundo con mejor expectativa de vida, pero su cantidad de medicos
# # por cada mil persona es baja, respecto de cuba,    pero su expectativa es 6 años mas (aprox)
# # la excepcion es san marino, que las dos variables son altas
# # creo que otras variables afectan esta relacion
# # no se como aplicar cambios en la data para ver com afecta el aumento de medicos en la expectaticva de vida
# # si aumenta o disminuye.

# %% [markdown]
# 6. Construye un gráfico para representar la población total de los países y su producto
# interno bruto. Prepara los datos y escoge el gráfico adecuado (si es necesario, limpia
# y/o transforma los datos). Justifica.

# %%
# reviso los valores nan para las columnas a graficar
print("** lista de valores nan ********")
print(df_world['Population'].isna().sum())
print(df_world['GDP'].isna().sum())
# Out:
# ** lista de valores nan ********
# 1
# 2

# %%
# reviso los valores atipicos con grafico boxplot
sns.boxplot(data=df_world, x='Population')
# Out:
# <Axes: xlabel='Population'>

# %%
# reviso los valores atipicos con grafico boxplot
sns.boxplot(data=df_world, x='GDP')
# Out:
# <Axes: xlabel='GDP'>

# %% [markdown]
# # solo quitare los nan de la grafica
# # respecto a los valores atipicos no los quitare, pues efectivamente existen diferencias
# # considerables (valores atipicos) en la poblacion y el producto interno bruto
# # y estimo que es la realidad, una tremenda diferencia entre los paises

# %%
# grafico 
plt.figure(figsize=(5, 5))
sns.set(style='whitegrid')

x_data = df_world['Population'].dropna()
y_data = df_world['GDP'].dropna()
sns.scatterplot(x=x_data, y=y_data, hue='Country', data=df_world, palette='Set3', legend=False)
plt.xlabel('Poblacion total')
plt.ylabel('Producto Interno Bruto')
plt.title('Poblacion total versus Producto interno bruto')
#plt.legend()
plt.show()

# %%
# reviso los paises ordenados por la columna poblacion
by_population = df_world.sort_values('Population',ascending=False)
by_population[['Country','Population']].head()
# Out:
#            Country    Population
# 36           China  1.397715e+09
# 77           India  1.366418e+09
# 186  United States  3.282395e+08
# 78       Indonesia  2.702039e+08
# 131       Pakistan  2.165653e+08

# %%
# reviso los paises ordenados por la columna GDP
by_gdp = df_world.sort_values('GDP',ascending=False)
by_gdp[['Country', 'GDP']].head(10)
# Out:
#             Country           GDP
# 186   United States  2.142770e+13
# 36            China  1.991000e+13
# 85            Japan  5.081770e+12
# 64          Germany  3.845630e+12
# 185  United Kingdom  2.827113e+12
# 60           France  2.715518e+12
# 77            India  2.611000e+12
# 162     South Korea  2.029000e+12
# 83            Italy  2.001244e+12
# 23           Brazil  1.839758e+12

# %% [markdown]
# # los paises que se escapan en el grafico con EE UU, China y la India
# # EEUU mas alto GDP y tercero en poblacion
# # China segundo mas alto en GDP y la mayor poblacion
# # India, segundo en poblacion y con un GDP en septimo lugar
#
# # son los valores mas disparados en el grafico
